# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
dfA=sns.load_dataset('mpg')
df=dfA
df
# Out:
#       mpg  cylinders  ...  origin                       name
# 0    18.0          8  ...     usa  chevrolet chevelle malibu
# 1    15.0          8  ...     usa          buick skylark 320
# 2    18.0          8  ...     usa         plymouth satellite
# 3    16.0          8  ...     usa              amc rebel sst
# 4    17.0          8  ...     usa                ford torino
# ..    ...        ...  ...     ...                        ...
# 393  27.0          4  ...     usa            ford mustang gl
# 394  44.0          4  ...  europe                  vw pickup
# 395  32.0          4  ...     usa              dodge rampage
# 396  28.0          4  ...     usa                ford ranger
# 397  31.0          4  ...     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
grouped=df.groupby(['origin'])
grouped.groups
dfE=df.iloc[grouped.groups['europe'].to_list(),:]
dfE
# Out:
#       mpg  cylinders  ...  origin                          name
# 19   26.0          4  ...  europe  volkswagen 1131 deluxe sedan
# 20   25.0          4  ...  europe                   peugeot 504
# 21   24.0          4  ...  europe                   audi 100 ls
# 22   25.0          4  ...  europe                      saab 99e
# 23   26.0          4  ...  europe                      bmw 2002
# ..    ...        ...  ...     ...                           ...
# 354  34.5          4  ...  europe                   renault 18i
# 359  28.1          4  ...  europe     peugeot 505s turbo diesel
# 360  30.7          6  ...  europe                  volvo diesel
# 375  36.0          4  ...  europe           volkswagen rabbit l
# 394  44.0          4  ...  europe                     vw pickup
#
# [70 rows x 9 columns]

# %%
plt.plot( 'model_year','mpg', data=dfE,color='green', marker='o', linestyle='dashed',
         linewidth=2, markersize=4)
plt.show()



plt.plot( 'origin', 'weight','r+', data=df,color='red',linewidth=2, markersize=12,label='line')
plt.xlabel('Origin')
plt.ylabel('Weights')
plt.title('Title')
plt.legend()

plt.show()
plt.plot( 'model_year','horsepower', data=df)
plt.show()

# %%
import numpy as np

 
plt.style.use('seaborn-darkgrid')
palette = plt.get_cmap('Set1')
plt.figure(figsize=(16,16))


def lineplotter(df,suptitle,plotDict,focus=None):
  
  for num,column in enumerate(df):
      
      cmap=plotDict['palette']
      if focus ==None:
        ax=plt.subplot(3,3, num+1)

        ax.plot(df[column], marker=plotDict['marker'], color=cmap(num), linewidth=plotDict['linewidth'], alpha=plotDict['alpha'], label=column)
        plt.title(column, loc='left', fontsize=suptitle['fontsize'], fontweight=suptitle['fontweight'], color=cmap(num) )
      else:
        ax=plt.subplot(1,1,1)

        if column in focus['name']:
          ax.plot(df[column], marker=plotDict['marker'], color=cmap(num), linewidth=plotDict['linewidth'], alpha=plotDict['alpha'], label=column)
          plt.title(column, loc='left', fontsize=suptitle['fontsize'], fontweight=suptitle['fontweight'], color=cmap(num) )
          plt.text((df[column].index[-1]), df[column].tail(1), column, horizontalalignment='left', size='large', color=cmap(num))
          
        else:
          ax.plot(df[column], marker=plotDict['marker'], color='gray', linewidth=plotDict['linewidth'], alpha=0.2, label=column)
          plt.title(column, loc='left', fontsize=suptitle['fontsize'], fontweight=suptitle['fontweight'], color=cmap(num) )
          loc,_=plt.xticks()
          
          plt.text((df[column].index[-1]), df[column].tail(1), column, horizontalalignment='left', size='small', color='grey')
 


  plt.suptitle("Subplots of features", fontsize=13, fontweight=0, color='black', style='italic', y=1.12)
  


df2=df.drop('origin', axis=1)
df2=df.iloc[df.groupby('origin').groups['europe'],:] # we choose only europe

suptitle={'fontsize':13,'fontweight':0,'color':'black','style':'italic'}
plotDict={'marker':'','palette':plt.get_cmap('Set1'),'linewidth':2,'alpha':1}

lineplotter(df2,suptitle=suptitle,plotDict=plotDict)

# %%
df2=df.iloc[df.groupby('origin').groups['europe'],:] # we choose only europe
df2=df2[['horsepower','acceleration','mpg','displacement']]
fig=plt.figure(figsize=(8,8))

suptitle={'fontsize':13,'fontweight':0,'color':'black','style':'italic'}
plotDict={'marker':'','palette':plt.get_cmap('Set1'),'linewidth':2,'alpha':1}

lineplotter(df2,suptitle=suptitle,plotDict=plotDict,focus={'name':['mpg','acceleration']})
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
import numpy as np
import pandas as pd

df=pd.DataFrame({'x': range(1,11), 'y1': np.random.randn(10), 
                 'y2': np.random.randn(10)+range(1,11), 
                 'y3': np.random.randn(10)+range(11,21),
                 'y4': np.random.randn(10)+range(6,16), 
                 'y5': np.random.randn(10)+range(4,14)+(0,0,0,0,0,0,0,-3,-8,-6), 
                 'y6': np.random.randn(10)+range(2,12), 
                 'y7': np.random.randn(10)+range(5,15), 
                 'y8': np.random.randn(10)+range(4,14) })
df['y1'].index.stop
# Out:
# 10

# %%
fig=plt.figure(figsize=(8,8))

suptitle={'fontsize':13,'fontweight':0,'color':'black','style':'italic'}
plotDict={'marker':'','palette':plt.get_cmap('Set1'),'linewidth':2,'alpha':1}
lineplotter(df,suptitle=suptitle,plotDict=plotDict,focus={'name':['y4','y3']})
plt.xticks(df['x'])
plt.xlabel('Time')
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
plt.hlines(y=df.y2, xmin=0, xmax=df.x, color='skyblue')
plt.plot(df.x, df.y2, "o")
 
# Add titles and axis names
plt.yticks(df.y2, df.x)
plt.title("A vertical lolipop plot", loc='left')
plt.xlabel('Value of the variable')
plt.ylabel('Group')

plt.show()
plt.vlines(x=df.y2, ymin=0, ymax=df.x, color='skyblue')
plt.plot(df.y2, df.x, "o")
 
# Add titles and axis names
plt.xticks(df.y2, df.x)
plt.title("A vertical lolipop plot", loc='left')
plt.xlabel('Value of the variable')
plt.ylabel('Group')
# Out:
# Text(0, 0.5, 'Group')

# %%
g = sns.FacetGrid(dfA, col='origin', hue='origin', col_wrap=3, )
 
# Add the line over the area with the plot function
g = g.map(plt.plot, 'model_year', 'weight')
 
# Fill the area with fill_between
g = g.map(plt.fill_between, 'model_year', 'weight', alpha=0.2).set_titles("{col_name} model_year")
 
# Control the title of each facet
g = g.set_titles("{col_name}")
 
# Add a title for the whole plo
plt.subplots_adjust(top=0.92)
g = g.fig.suptitle('Car Weights among countries ',y=1.25)
 
plt.show()


g = sns.FacetGrid(dfA, col='origin', hue='origin', col_wrap=3, )
 
# Add the line over the area with the plot function
g = g.map(plt.plot, 'model_year', 'acceleration')
 
# Fill the area with fill_between
g = g.map(plt.fill_between, 'model_year', 'acceleration', alpha=0.2).set_titles("{col_name} model_year")
 
# Control the title of each facet
g = g.set_titles("{col_name}")
 
# Add a title for the whole plo
plt.subplots_adjust(top=0.92)
g = g.fig.suptitle('Acceleration among countries ',y=1.25)
 
plt.show()

# %%
import pandas
from pandas.plotting import parallel_coordinates
plt.figure(figsize=(12,12))
# Take the iris dataset
import seaborn as sns
data = sns.load_dataset('iris')
 
# Make the plot
parallel_coordinates(data, 'species', colormap=plt.get_cmap("Set2"))
plt.show()
