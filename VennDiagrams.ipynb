# %%
# Import the library
import matplotlib.pyplot as plt
from matplotlib_venn import venn3
 
# Custom text labels: change the label of group A
v=venn3(subsets = (2, 8, 22, 6,9,4,2), set_labels = ('Group A', 'Group B', 'Group C'))
#subsets 100,010,110,001,101,011,111
v.get_label_by_id('A').set_text('Changed the name')
plt.show()
 
# Line style: can be 'dashed' or 'dotted' for example
v=venn3(subsets = (10, 8, 22, 6,9,4,2), set_labels = ('Group A', 'Group B', 'Group C'))
#subsets 100,010,110,001,101,011,111
plt.show()

v=venn3(subsets = (10, 8, 22, 6,9,4,2), set_labels = ('Group A', 'Group B', 'Group C'))
# Color
v.get_patch_by_id('100').set_alpha(1.0)
v.get_patch_by_id('100').set_color('white')
plt.show()

# %%
import seaborn as sns

df=sns.load_dataset('iris')



set1 = set(['F','F','F','M','F','LGBT+','NM','F','M','KS'])
set2 = set(['F','M','M','M','NM','NM','LGBT','M','LGBT+','KY','F','F','M'])
set3 = set(['NM','F','F','M','NM','NM','F','M','F','F','F','M','KH'])

venn3([set1, set2, set3], ('Ankara', 'Adana', 'Mersin'))

plt.show()
